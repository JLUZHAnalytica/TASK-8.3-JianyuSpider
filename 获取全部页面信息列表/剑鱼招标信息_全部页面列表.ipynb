# %%
import requests
import json
response = requests.post(
    url='https://www.jianyu360.com/front/pcAjaxReq',
    headers={
        "accept": "*/*",
        "Accept-encoding": "gzip, deflate, br",
        "accept-language": "zh-CN,zh;q=0.9",
        "content-length": "168",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "cookie": "SESSIONID=7359f1a8169e51397de48e8c74f95ff8fc19f2fb; SESSIONID=7359f1a8169e51397de48e8c74f95ff8fc19f2fb; UM_distinctid=173b412a93a252-006a51ec957038-3323765-1fa400-173b412a93bad4; CNZZDATA1261815924=1311445470-1596448943-https%253A%252F%252Fwww.jianyu360.com%252F%7C1596454345; selectNum=1; Hm_lvt_72331746d85dcac3dac65202d103e5d9=1596453907,1596457215; Hm_lpvt_72331746d85dcac3dac65202d103e5d9=1596457241; userid_secure=",
        "origin": "https://www.jianyu360.com",
        "referer": "https://www.jianyu360.com/jylab/supsearch/index.html",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
        "x-requested-with": "XMLHttpRequest"
            },
    data={
        "pageNumber": "11",#当前页
        "reqType": "bidSearch",
        "searchvalue": "虚拟仿真",
        "area": "",
        "subtype":"" ,
        "publishtime": "",
        "selectType": "title",
        "minprice": "",
        "maxprice": "",
        "industry": "",
        "tabularflag": "Y",
            }

)
dict=response.content.decode()
data = json.loads(dict)
data = data.get("list")
data = json.dumps(data,ensure_ascii=False)
print(data+"\n")
with open('brief_list.json', 'a+',encoding='utf-8') as f:  #本地也保留一份 
        f.write(data+'\n')
        f.close()
# Out:
# [{"_id": "ABCY2FddikFKyA7JFV6c2I%2FIzNfCSd3cXhyKA4jJi9FZFJwHA1UCZ8%3D", "area": "四川", "areaadd": "SC", "buyerclass": "学校", "city": "成都市", "detail": "", "href": "ABCYFwEdDJYKys7EmN0cFwkDDAoESRjcUJwKB4gKgACDw0G9Q%3D%3D", "indadd": "", "publishtime": 1594715580, "stypeadd": "BG", "subtype": "变更", "title": "四川师范大学2020年教务处虚拟仿真平台采购项目公开招标采购更正公告", "toptype": "招标"}, {"_id": "ABCY2FddilYNykvAmd6c2I%2FIzNfCSd3cXhyKA4gOC43Y3lwBFJUCj4%3D", "area": "河北", "areaadd": "HB", "buyerclass": "学校", "city": "石家庄市", "detail": "", "href": "ABCYHZZdj0vBS87AnN1c3IsMTIoSCNjR3B%2FKx40Kg8SDw0H7g%3D%3D", "indadd": "XXJS", "industry": "信息技术", "publishtime": 1594715557, "s_subscopeclass": "信息技术_软件开发,信息技术_其他", "stypeadd": "FB", "subtype": "废标", "title": "河北科技大学数据查询数据库及虚拟仿真系统采购公开招标废标公告", "toptype": "结果"}, {"_id": "ABCY2FddikFLyM4GWd6c2I%2FIzNfCSd3cXhyKA4jKD0waGhwHCNUCdU%3D", "area": "山东", "areaadd": "SD", "bidamount": 649000, "buyerclass": "学校", "city": "济南市", "detail": "", "href": "ABCY1xdczwFBS86AnN3dXI8CDAoIxFjYVJx
# ...
